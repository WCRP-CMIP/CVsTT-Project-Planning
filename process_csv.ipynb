# %% [markdown]
# # CSV to create issues and add to Project Board
#
# Complete system with git API calls and bulk creation of issues.

# %%
# Setup
import pandas as pd
from cmipld.utils.git.projects import *

ORG = "WCRP-CMIP"
REPO = "CVsTT-Project-Planning"

ghutils = GitHubUtils()
teams  = TeamManager()
issue_mgr = IssueManager()
label_mgr = LabelManager()
milestone_mgr = MilestoneManager()
project_mgr = ProjectManager()

print("✅ Ready - all APIs initialized.")
# Out:
# ✅ Ready - all APIs initialized.

# %%
# project_mgr.list_all_projects(ORG)
pid = 'PVT_kwDOATRwu84A60Fm'

# %%
attributes = pd.read_csv('global_attributes_tasks.csv')
attributes.head()
# Out:
#                title  start_date    end_date             milestone  \
# 0  Global_attributes  2025-05-22  2025-06-05  DRS, GlobalAttribute
# 1     variableRootDD  2025-05-29  2025-06-12  DRS, GlobalAttribute
# 2  horizontalLabelDD  2025-05-29  2025-06-12  DRS, GlobalAttribute
# 3         verticalDD  2025-05-29  2025-06-12  DRS, GlobalAttribute
# 4    temporalLabelDD  2025-05-29  2025-06-12  DRS, GlobalAttribute
#
#                                    labels assignees  \
# 0   DRS,GlobalAttribute,CVsTT,DataModeler     CVsTT
# 1            DRS,GlobalAttribute,CVsTT,DR     CVsTT
# 2  DRS,GlobalAttribute,CVsTT,KarlDocument     CVsTT
# 3  DRS,GlobalAttribute,CVsTT,KarlDocument     CVsTT
# 4  DRS,GlobalAttribute,CVsTT,KarlDocument     CVsTT
#
#                                              content
# 0  # Global Attribute Review\n\n## Status\n- [ ] ...
# 1  # Global Attribute Review\n\n## Status\n- [ ] ...
# 2  # Global Attribute Review\n\n## Status\n- [ ] ...
# 3  # Global Attribute Review\n\n## Status\n- [ ] ...
# 4  # Global Attribute Review\n\n## Status\n- [ ] ...

# %%
other = pd.read_csv('framework_tasks.csv')
other['assignees']=''
other.head()
# Out:
#                                                title  start_date    end_date  \
# 0                         JSONLD rename homodeniguty  2025-05-22  2025-07-03
# 1                       Match CV names with DD names  2025-05-22  2025-11-06
# 2                               README documentation  2025-05-22  2025-07-03
# 3  Get Scientific members to populate field descr...  2025-06-19  2025-11-06
# 4                    Symbiosis of esgvoc and cmip-ld  2025-05-22  2025-06-19
#
#    milestone                         labels assignees  \
# 0  Framework                Framework,CVsTT
# 1  Framework                Framework,CVsTT
# 2  Framework  Framework,CVsTT,Documentation
# 3  Framework  Framework,CVsTT,Documentation
# 4  Framework    Framework,CVsTT,Integration
#
#                                              content
# 0  # Framework Task Review\n\n## Status\n- [ ] St...
# 1  # Framework Task Review\n\n## Status\n- [x] On...
# 2  # Framework Task Review\n\n## Status\n- [ ] St...
# 3  # Framework Task Review\n\n## Status\n- [ ] Ne...
# 4  # Framework Task Review\n\n## Status\n- [x] On...

# %%
def create_new(data):
    labels = set()
    milestones = set()
    assign = set()

    # add all the labels and milestones from the attributes
    for i, row in data.iterrows():
            
            labels = labels.union(set(row['labels'].split(',')))
            milestones = milestones.union(set(row['milestone'].split(',')))
            assign = assign.union(set(row['assignees'].split(',')))
            
    label_mgr.ensure_labels_exist(ORG, REPO, [{"name":i,"description":i} for i in labels])
    [milestone_mgr.ensure_milestone_exists(ORG, REPO, j) for j in [{"title":i,"description":i} for i in milestones]]
    [teams.create_child_team(ORG, 'CVsTT', i, description=None) for i in assign if i != '']




    idata=[]
    for i, row in data.iterrows():
            idata .append({
            "title": row['title'],
            "content": f'{row["content"]}',
            "labels": row['labels'].split(','),
            "milestone": row['milestone'].split(',')[0],
            "start_date": row['start_date'],
            "end_date": row['end_date'],
            "teams": row['assignees'].split(','),
        })

    # Create all roadmap issues with project integration
    created, failed = issue_mgr.create_issues_bulk(
        ORG, 
        REPO, 
        idata,
        add_to_project_id=pid
    )

        
    for i in created:
        t = list(filter(lambda x: x['title'] == i['title'],idata))[0]
        for t2 in t['teams']:
            teams.assign_issue_to_team(i['url'], ORG,t2)

# %%
# create_new(attributes)
# Out:
# 🏷️ Ensuring labels exist...
#
# 🏷️ Checking if label 'New' exists...
# 🔄 Running: gh api /repos/WCRP-CMIP/CVsTT-Project-Planning/labels/New
# Return code: 0
# Stdout: {
#   "id": 8736415893,
#   "node_id": "LA_kwDOO23ghc8AAAACCLsglQ",
#   "url": "https://api.github.com/repos/WCRP-CMIP/CVsTT-Project-Planning/labels/New",
#   "name": "New",
#   "color": "FFFFFF",
#   "default": ...
# ✅ Label 'New' exists
#
# 🏷️ Checking if label 'GlobalAttribute' exists...
# 🔄 Running: gh api /repos/WCRP-CMIP/CVsTT-Project-Planning/labels/GlobalAttribute
# Return code: 0
# Stdout: {
#   "id": 8736415900,
#   "node_id": "LA_kwDOO23ghc8AAAACCLsgnA",
#   "url": "https://api.github.com/repos/WCRP-CMIP/CVsTT-Project-Planning/labels/GlobalAttribute",
#   "name": "GlobalAttribute",
#   "color":...
# ✅ Label 'GlobalAttribute' exists
#
# 🏷️ Checking if label 'Input4Mips' exists...
# 🔄 Running: gh api /repos/WCRP-CMIP/CVsTT-Project-Planning/labels/Input4Mips
# Return code: 0
# Stdout: {
#   "id": 8736415916,
#   "node_id": "LA_kwDOO23ghc8AAAACCLsgrA",
#   "url": "https://api.github.com/repos/WCRP-CMIP/CVsTT-Project-Planning/labels/Input4Mips",
#   "name": "Input4Mips",
#   "color": "FFFFFF",...
# ✅ Label 'Input4Mips' exists
#
# 🏷️ Checking if label 'CMOR' exists...
# 🔄 Running: gh api /repos/WCRP-CMIP/CVsTT-Project-Planning/labels/CMOR
# Return code: 0
# Stdout: {
#   "id": 8736415930,
#   "node_id": "LA_kwDOO23ghc8AAAACCLsgug",
#   "url": "https://api.github.com/repos/WCRP-CMIP/CVsTT-Project-Planning/labels/CMOR",
#   "name": "CMOR",
#   "color": "FFFFFF",
#   "default"...
# ✅ Label 'CMOR' exists
#
# 🏷️ Checking if label 'MipEra' exists...
# 🔄 Running: gh api /repos/WCRP-CMIP/CVsTT-Project-Planning/labels/MipEra
# Return code: 0
# Stdout: {
#   "id": 8736415984,
#   "node_id": "LA_kwDOO23ghc8AAAACCLsg8A",
#   "url": "https://api.github.com/repos/WCRP-CMIP/CVsTT-Project-Planning/labels/MipEra",
#   "name": "MipEra",
#   "color": "FFFFFF",
#   "defa...
# ✅ Label 'MipEra' exists
#
# 🏷️ Checking if label 'DataModeler' exists...
# 🔄 Running: gh api /repos/WCRP-CMIP/CVsTT-Project-Planning/labels/DataModeler
# Return code: 0
# Stdout: {
#   "id": 8736416059,
#   "node_id": "LA_kwDOO23ghc8AAAACCLshOw",
#   "url": "https://api.github.com/repos/WCRP-CMIP/CVsTT-Project-Planning/labels/DataModeler",
#   "name": "DataModeler",
#   "color": "FFFFFF...
# ✅ Label 'DataModeler' exists
#
# 🏷️ Checking if label 'GoogleSpreadsheet' exists...
# 🔄 Running: gh api /repos/WCRP-CMIP/CVsTT-Project-Planning/labels/GoogleSpreadsheet
# Return code: 0
# Stdout: {
#   "id": 8736416103,
#   "node_id": "LA_kwDOO23ghc8AAAACCLshZw",
#   "url": "https://api.github.com/repos/WCRP-CMIP/CVsTT-Project-Planning/labels/GoogleSpreadsheet",
#   "name": "GoogleSpreadsheet",
#   "col...
# ✅ Label 'GoogleSpreadsheet' exists
#
# 🏷️ Checking if label 'DR' exists...
# 🔄 Running: gh api /repos/WCRP-CMIP/CVsTT-Project-Planning/labels/DR
# Return code: 0
# Stdout: {
#   "id": 8736416109,
#   "node_id": "LA_kwDOO23ghc8AAAACCLshbQ",
#   "url": "https://api.github.com/repos/WCRP-CMIP/CVsTT-Project-Planning/labels/DR",
#   "name": "DR",
#   "color": "FFFFFF",
#   "default": fa...
# ✅ Label 'DR' exists
#
# 🏷️ Checking if label 'WCRP' exists...
# 🔄 Running: gh api /repos/WCRP-CMIP/CVsTT-Project-Planning/labels/WCRP
# Return code: 0
# Stdout: {
#   "id": 8736416110,
#   "node_id": "LA_kwDOO23ghc8AAAACCLshbg",
#   "url": "https://api.github.com/repos/WCRP-CMIP/CVsTT-Project-Planning/labels/WCRP",
#   "name": "WCRP",
#   "color": "FFFFFF",
#   "default"...
# ✅ Label 'WCRP' exists
#
# 🏷️ Checking if label 'DRS' exists...
# 🔄 Running: gh api /repos/WCRP-CMIP/CVsTT-Project-Planning/labels/DRS
# Return code: 0
# Stdout: {
#   "id": 8736416118,
#   "node_id": "LA_kwDOO23ghc8AAAACCLshdg",
#   "url": "https://api.github.com/repos/WCRP-CMIP/CVsTT-Project-Planning/labels/DRS",
#   "name": "DRS",
#   "color": "FFFFFF",
#   "default": ...
# ✅ Label 'DRS' exists
#
# 🏷️ Checking if label 'Obs4Mips' exists...
# 🔄 Running: gh api /repos/WCRP-CMIP/CVsTT-Project-Planning/labels/Obs4Mips
# Return code: 0
# Stdout: {
#   "id": 8736416140,
#   "node_id": "LA_kwDOO23ghc8AAAACCLshjA",
#   "url": "https://api.github.com/repos/WCRP-CMIP/CVsTT-Project-Planning/labels/Obs4Mips",
#   "name": "Obs4Mips",
#   "color": "FFFFFF",
#   "...
# ✅ Label 'Obs4Mips' exists
#
# 🏷️ Checking if label 'CMIP' exists...
# 🔄 Running: gh api /repos/WCRP-CMIP/CVsTT-Project-Planning/labels/CMIP
# Return code: 0
# Stdout: {
#   "id": 8736416193,
#   "node_id": "LA_kwDOO23ghc8AAAACCLshwQ",
#   "url": "https://api.github.com/repos/WCRP-CMIP/CVsTT-Project-Planning/labels/CMIP",
#   "name": "CMIP",
#   "color": "FFFFFF",
#   "default"...
# ✅ Label 'CMIP' exists
#
# 🏷️ Checking if label 'Other' exists...
# 🔄 Running: gh api /repos/WCRP-CMIP/CVsTT-Project-Planning/labels/Other
# Return code: 0
# Stdout: {
#   "id": 8736416243,
#   "node_id": "LA_kwDOO23ghc8AAAACCLsh8w",
#   "url": "https://api.github.com/repos/WCRP-CMIP/CVsTT-Project-Planning/labels/Other",
#   "name": "Other",
#   "color": "FFFFFF",
#   "defaul...
# ✅ Label 'Other' exists
#
# 🏷️ Checking if label 'KarlDocument' exists...
# 🔄 Running: gh api /repos/WCRP-CMIP/CVsTT-Project-Planning/labels/KarlDocument
# Return code: 0
# Stdout: {
#   "id": 8736416263,
#   "node_id": "LA_kwDOO23ghc8AAAACCLsiBw",
#   "url": "https://api.github.com/repos/WCRP-CMIP/CVsTT-Project-Planning/labels/KarlDocument",
#   "name": "KarlDocument",
#   "color": "FFFF...
# ✅ Label 'KarlDocument' exists
#
# 🏷️ Checking if label 'OldDocuments' exists...
# 🔄 Running: gh api /repos/WCRP-CMIP/CVsTT-Project-Planning/labels/OldDocuments
# Return code: 0
# Stdout: {
#   "id": 8736416295,
#   "node_id": "LA_kwDOO23ghc8AAAACCLsiJw",
#   "url": "https://api.github.com/repos/WCRP-CMIP/CVsTT-Project-Planning/labels/OldDocuments",
#   "name": "OldDocuments",
#   "color": "FFFF...
# ✅ Label 'OldDocuments' exists
#
# 🏷️ Checking if label 'CVsTT' exists...
# 🔄 Running: gh api /repos/WCRP-CMIP/CVsTT-Project-Planning/labels/CVsTT
# Return code: 0
# Stdout: {
#   "id": 8736386227,
#   "node_id": "LA_kwDOO23ghc8AAAACCLqssw",
#   "url": "https://api.github.com/repos/WCRP-CMIP/CVsTT-Project-Planning/labels/CVsTT",
#   "name": "CVsTT",
#   "color": "FFFFFF",
#   "defaul...
# ✅ Label 'CVsTT' exists
#
# 🏷️ Checking if label 'TrackingId' exists...
# 🔄 Running: gh api /repos/WCRP-CMIP/CVsTT-Project-Planning/labels/TrackingId
# Return code: 0
# Stdout: {
#   "id": 8736416299,
#   "node_id": "LA_kwDOO23ghc8AAAACCLsiKw",
#   "url": "https://api.github.com/repos/WCRP-CMIP/CVsTT-Project-Planning/labels/TrackingId",
#   "name": "TrackingId",
#   "color": "FFFFFF",...
# ✅ Label 'TrackingId' exists
#
# 🏷️ Checking if label 'OldCV' exists...
# 🔄 Running: gh api /repos/WCRP-CMIP/CVsTT-Project-Planning/labels/OldCV
# Return code: 0
# Stdout: {
#   "id": 8736416313,
#   "node_id": "LA_kwDOO23ghc8AAAACCLsiOQ",
#   "url": "https://api.github.com/repos/WCRP-CMIP/CVsTT-Project-Planning/labels/OldCV",
#   "name": "OldCV",
#   "color": "FFFFFF",
#   "defaul...
# ✅ Label 'OldCV' exists
#
# 🏷️ Checking if label 'IssueRegister' exists...
# 🔄 Running: gh api /repos/WCRP-CMIP/CVsTT-Project-Planning/labels/IssueRegister
# Return code: 0
# Stdout: {
#   "id": 8736416327,
#   "node_id": "LA_kwDOO23ghc8AAAACCLsiRw",
#   "url": "https://api.github.com/repos/WCRP-CMIP/CVsTT-Project-Planning/labels/IssueRegister",
#   "name": "IssueRegister",
#   "color": "FF...
# ✅ Label 'IssueRegister' exists
#
# 🏷️ Checking if label 'EMD' exists...
# 🔄 Running: gh api /repos/WCRP-CMIP/CVsTT-Project-Planning/labels/EMD
# Return code: 0
# Stdout: {
#   "id": 8736416376,
#   "node_id": "LA_kwDOO23ghc8AAAACCLsieA",
#   "url": "https://api.github.com/repos/WCRP-CMIP/CVsTT-Project-Planning/labels/EMD",
#   "name": "EMD",
#   "color": "FFFFFF",
#   "default": ...
# ✅ Label 'EMD' exists
#
# 🏷️ Checking if label 'Activity' exists...
# 🔄 Running: gh api /repos/WCRP-CMIP/CVsTT-Project-Planning/labels/Activity
# Return code: 0
# Stdout: {
#   "id": 8736416448,
#   "node_id": "LA_kwDOO23ghc8AAAACCLsiwA",
#   "url": "https://api.github.com/repos/WCRP-CMIP/CVsTT-Project-Planning/labels/Activity",
#   "name": "Activity",
#   "color": "FFFFFF",
#   "...
# ✅ Label 'Activity' exists
#
# 🏷️ Checking if label 'Info' exists...
# 🔄 Running: gh api /repos/WCRP-CMIP/CVsTT-Project-Planning/labels/Info
# Return code: 0
# Stdout: {
#   "id": 8736416450,
#   "node_id": "LA_kwDOO23ghc8AAAACCLsiwg",
#   "url": "https://api.github.com/repos/WCRP-CMIP/CVsTT-Project-Planning/labels/Info",
#   "name": "Info",
#   "color": "FFFFFF",
#   "default"...
# ✅ Label 'Info' exists
# ✅ Labels management completed
#    Created: 0 labels
#    Existing: 22 labels
#
# 🎯 Ensuring milestone exists...
#
# 💯 Checking if milestone 'DRS' exists...
# 🔄 Running: gh api /repos/WCRP-CMIP/CVsTT-Project-Planning/milestones
# Return code: 0
# Stdout: [
#   {
#     "url": "https://api.github.com/repos/WCRP-CMIP/CVsTT-Project-Planning/milestones/1",
#     "html_url": "https://github.com/WCRP-CMIP/CVsTT-Project-Planning/milestone/1",
#     "labels_url": "htt...
# ✅ Milestone 'DRS' exists with number: 2
#
# 🎯 Ensuring milestone exists...
#
# 💯 Checking if milestone 'EMD' exists...
# 🔄 Running: gh api /repos/WCRP-CMIP/CVsTT-Project-Planning/milestones
# Return code: 0
# Stdout: [
#   {
#     "url": "https://api.github.com/repos/WCRP-CMIP/CVsTT-Project-Planning/milestones/1",
#     "html_url": "https://github.com/WCRP-CMIP/CVsTT-Project-Planning/milestone/1",
#     "labels_url": "htt...
# ✅ Milestone 'EMD' exists with number: 3
#
# 🎯 Ensuring milestone exists...
#
# 💯 Checking if milestone ' GlobalAttribute' exists...
# 🔄 Running: gh api /repos/WCRP-CMIP/CVsTT-Project-Planning/milestones
# Return code: 0
# Stdout: [
#   {
#     "url": "https://api.github.com/repos/WCRP-CMIP/CVsTT-Project-Planning/milestones/1",
#     "html_url": "https://github.com/WCRP-CMIP/CVsTT-Project-Planning/milestone/1",
#     "labels_url": "htt...
# ✅ Milestone ' GlobalAttribute' exists with number: 4
#
# 🎯 Ensuring milestone exists...
#
# 💯 Checking if milestone 'Other' exists...
# 🔄 Running: gh api /repos/WCRP-CMIP/CVsTT-Project-Planning/milestones
# Return code: 0
# Stdout: [
#   {
#     "url": "https://api.github.com/repos/WCRP-CMIP/CVsTT-Project-Planning/milestones/1",
#     "html_url": "https://github.com/WCRP-CMIP/CVsTT-Project-Planning/milestone/1",
#     "labels_url": "htt...
# ✅ Milestone 'Other' exists with number: 5
#
# 🎯 Ensuring milestone exists...
#
# 💯 Checking if milestone 'Info' exists...
# 🔄 Running: gh api /repos/WCRP-CMIP/CVsTT-Project-Planning/milestones
# Return code: 0
# Stdout: [
#   {
#     "url": "https://api.github.com/repos/WCRP-CMIP/CVsTT-Project-Planning/milestones/1",
#     "html_url": "https://github.com/WCRP-CMIP/CVsTT-Project-Planning/milestone/1",
#     "labels_url": "htt...
# ✅ Milestone 'Info' exists with number: 6
#
# 🎯 Ensuring milestone exists...
#
# 💯 Checking if milestone 'CMOR' exists...
# 🔄 Running: gh api /repos/WCRP-CMIP/CVsTT-Project-Planning/milestones
# Return code: 0
# Stdout: [
#   {
#     "url": "https://api.github.com/repos/WCRP-CMIP/CVsTT-Project-Planning/milestones/1",
#     "html_url": "https://github.com/WCRP-CMIP/CVsTT-Project-Planning/milestone/1",
#     "labels_url": "htt...
# ✅ Milestone 'CMOR' exists with number: 7
#
# ➕ Creating child team 'CVsTT' under 'CVsTT'...
# 🔄 Running: gh api /orgs/WCRP-CMIP/teams/CVsTT
# Return code: 0
# Stdout: {
#   "name": "CVsTT",
#   "id": 12650392,
#   "node_id": "T_kwDOATRwu84AwQeY",
#   "slug": "cvstt",
#   "description": "CVs task team",
#   "privacy": "closed",
#   "notification_setting": "notifications_enabled",...
#
# ➕ Creating team 'CVsTT'...
# 🔄 Running: gh api /orgs/WCRP-CMIP/teams --method POST --input -
# Return code: 1
# Stdout: {
#   "message": "Validation Failed",
#   "errors": [
#     {
#       "resource": "Team",
#       "code": "unprocessable",
#       "field": "data",
#       "message": "Name must be unique for this org"
#     }
#   ],
#  ...
# Stderr: gh: Validation Failed (HTTP 422)
#
# ❌ Error creating team 'CVsTT': Command failed: api /orgs/WCRP-CMIP/teams --method POST --input -
# Error: gh: Validation Failed (HTTP 422)
#
#
# 🚀 Bulk creating 40 issues...
#
# [1/40] Processing: Global_attributes
#
# ➕ Creating issue: Global_attributes
# 🔄 Running: gh issue create --repo WCRP-CMIP/CVsTT-Project-Planning --title Global_attributes --body "# Global Attribute Review
#
# ## Status
# - [ ] Started
# - [ ] Discussed
# - [ ] Awaiting feedback
#
# ## Details
# DataModeler task - 95% complete" --label DRS --label GlobalAttribute --label CVsTT --label DataModeler --milestone DRS
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/10
# ✅ Issue created successfully
#
# 🔍 Getting issue information from: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/10
# 🔄 Running: gh issue view https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/10 --json id,number,title,body,state
# Return code: 0
# Stdout: {
#   "body": "\"# Global Attribute Review\n\n## Status\n- [ ] Started\n- [ ] Discussed  \n- [ ] Awaiting feedback\n\n## Details\nDataModeler task - 95% complete\"",
#   "id": "I_kwDOO23ghc66Jtjl",
#   "num...
# ✅ Issue retrieved: #10 - Global_attributes
#
# ➕ Adding issue to project with dates...
#
# ➕ Adding issue to project...
# 🔄 Running: gh api graphql -f query=
#         mutation($projectId: ID!, $contentId: ID!) {
#           addProjectV2ItemById(input: {projectId: $projectId, contentId: $contentId}) {
#             item {
#               id
#             }
#           }
#         }
#          -F projectId=PVT_kwDOATRwu84A60Fm -F contentId=I_kwDOO23ghc66Jtjl
# Return code: 0
# Stdout: {
#   "data": {
#     "addProjectV2ItemById": {
#       "item": {
#         "id": "PVTI_lADOATRwu84A60FmzgbMfno"
#       }
#     }
#   }
# }
# ✅ Issue added to project
#
# 🔍 Searching for issue in project...
# 🔄 Running: gh api graphql -f query=
#         query ($projectId: ID!) {
#           node(id: $projectId) {
#             ... on ProjectV2 {
#               items(first: 100) {
#                 nodes {
#                   id
#                   content {
#                     ... on Issue {
#                       id
#                       number
#                       title
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#          -F projectId=PVT_kwDOATRwu84A60Fm
# Return code: 0
# Stdout: {
#   "data": {
#     "node": {
#       "items": {
#         "nodes": [
#           {
#             "id": "PVTI_lADOATRwu84A60FmzgbMdYo",
#             "content": {
#               "id": "I_kwDOO23ghc66JWE3",
#        ...
# Found 9 items in project
# ℹ️ Issue not found in project
# ❌ Could not find issue in project after adding
# ✅ Created successfully
#
# [2/40] Processing: variableRootDD
#
# ➕ Creating issue: variableRootDD
# 🔄 Running: gh issue create --repo WCRP-CMIP/CVsTT-Project-Planning --title variableRootDD --body "# Global Attribute Review
#
# ## Status
# - [ ] Started
# - [ ] Discussed
# - [ ] Awaiting feedback
#
# ## Details
# DR responsibility" --label DRS --label GlobalAttribute --label CVsTT --label DR --milestone DRS
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/11
# ✅ Issue created successfully
#
# 🔍 Getting issue information from: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/11
# 🔄 Running: gh issue view https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/11 --json id,number,title,body,state
# Return code: 0
# Stdout: {
#   "body": "\"# Global Attribute Review\n\n## Status\n- [ ] Started\n- [ ] Discussed\n- [ ] Awaiting feedback\n\n## Details\nDR responsibility\"",
#   "id": "I_kwDOO23ghc66JtlP",
#   "number": 11,
#   "sta...
# ✅ Issue retrieved: #11 - variableRootDD
#
# ➕ Adding issue to project with dates...
#
# ➕ Adding issue to project...
# 🔄 Running: gh api graphql -f query=
#         mutation($projectId: ID!, $contentId: ID!) {
#           addProjectV2ItemById(input: {projectId: $projectId, contentId: $contentId}) {
#             item {
#               id
#             }
#           }
#         }
#          -F projectId=PVT_kwDOATRwu84A60Fm -F contentId=I_kwDOO23ghc66JtlP
# Return code: 0
# Stdout: {
#   "data": {
#     "addProjectV2ItemById": {
#       "item": {
#         "id": "PVTI_lADOATRwu84A60FmzgbMfoE"
#       }
#     }
#   }
# }
# ✅ Issue added to project
#
# 🔍 Searching for issue in project...
# 🔄 Running: gh api graphql -f query=
#         query ($projectId: ID!) {
#           node(id: $projectId) {
#             ... on ProjectV2 {
#               items(first: 100) {
#                 nodes {
#                   id
#                   content {
#                     ... on Issue {
#                       id
#                       number
#                       title
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#          -F projectId=PVT_kwDOATRwu84A60Fm
# Return code: 0
# Stdout: {
#   "data": {
#     "node": {
#       "items": {
#         "nodes": [
#           {
#             "id": "PVTI_lADOATRwu84A60FmzgbMdYo",
#             "content": {
#               "id": "I_kwDOO23ghc66JWE3",
#        ...
# Found 11 items in project
# ✅ Issue found in project! Item ID: PVTI_lADOATRwu84A60FmzgbMfoE
#
# 🔍 Getting project fields...
# 🔄 Running: gh api graphql -f query=
#         query ($projectId: ID!) {
#           node(id: $projectId) {
#             ... on ProjectV2 {
#               fields(first: 50) {
#                 nodes {
#                   __typename
#                   ... on ProjectV2FieldCommon {
#                     id
#                     name
#                     dataType
#                   }
#                 }
#               }
#             }
#           }
#         }
#          -F projectId=PVT_kwDOATRwu84A60Fm
# Return code: 0
# Stdout: {
#   "data": {
#     "node": {
#       "fields": {
#         "nodes": [
#           {
#             "__typename": "ProjectV2Field",
#             "id": "PVTF_lADOATRwu84A60FmzgvTD3k",
#             "name": "Title",
# ...
#   - Title: PVTF_lADOATRwu84A60FmzgvTD3k
#   - Assignees: PVTF_lADOATRwu84A60FmzgvTD3o
#   - Status: PVTSSF_lADOATRwu84A60FmzgvTD3s
#   - Labels: PVTF_lADOATRwu84A60FmzgvTD3w
#   - Linked pull requests: PVTF_lADOATRwu84A60FmzgvTD30
#   - Milestone: PVTF_lADOATRwu84A60FmzgvTD34
#   - Repository: PVTF_lADOATRwu84A60FmzgvTD38
#   - Reviewers: PVTF_lADOATRwu84A60FmzgvTD4E
#   - Parent issue: PVTF_lADOATRwu84A60FmzgvTD4I
#   - Sub-issues progress: PVTF_lADOATRwu84A60FmzgvTD4M
#   - Team: PVTSSF_lADOATRwu84A60FmzgvTEAA
#   - Iteration: PVTIF_lADOATRwu84A60FmzgvTEAE
#   - Quarter: PVTIF_lADOATRwu84A60FmzgvTEAI
#   - Start date: PVTF_lADOATRwu84A60FmzgvTEAM
#   - End date: PVTF_lADOATRwu84A60FmzgvTEAQ
#
# 📝 Updating multiple project fields...
# 📝 Updating 'Start date' to '2025-05-29'
# 🔄 Running: gh api graphql -f query=
#             mutation($projectId: ID!, $itemId: ID!, $fieldId: ID!, $value: Date!) {
#               updateProjectV2ItemFieldValue(input: {
#                 projectId: $projectId
#                 itemId: $itemId
#                 fieldId: $fieldId
#                 value: { date: $value }
#               }) {
#                 projectV2Item {
#                   id
#                 }
#               }
#             }
#              -F projectId=PVT_kwDOATRwu84A60Fm -F itemId=PVTI_lADOATRwu84A60FmzgbMfoE -F fieldId=PVTF_lADOATRwu84A60FmzgvTEAM -F value=2025-05-29
# Return code: 0
# Stdout: {
#   "data": {
#     "updateProjectV2ItemFieldValue": {
#       "projectV2Item": {
#         "id": "PVTI_lADOATRwu84A60FmzgbMfoE"
#       }
#     }
#   }
# }
# ✅ 'Start date' updated successfully
# 📝 Updating 'End date' to '2025-06-12'
# 🔄 Running: gh api graphql -f query=
#             mutation($projectId: ID!, $itemId: ID!, $fieldId: ID!, $value: Date!) {
#               updateProjectV2ItemFieldValue(input: {
#                 projectId: $projectId
#                 itemId: $itemId
#                 fieldId: $fieldId
#                 value: { date: $value }
#               }) {
#                 projectV2Item {
#                   id
#                 }
#               }
#             }
#              -F projectId=PVT_kwDOATRwu84A60Fm -F itemId=PVTI_lADOATRwu84A60FmzgbMfoE -F fieldId=PVTF_lADOATRwu84A60FmzgvTEAQ -F value=2025-06-12
# Return code: 0
# Stdout: {
#   "data": {
#     "updateProjectV2ItemFieldValue": {
#       "projectV2Item": {
#         "id": "PVTI_lADOATRwu84A60FmzgbMfoE"
#       }
#     }
#   }
# }
# ✅ 'End date' updated successfully
# ✅ Updated 2/2 fields successfully
# ✅ Issue added to project with dates: 2025-05-29 to 2025-06-12
# ✅ Created successfully
#
# [3/40] Processing: horizontalLabelDD
#
# ➕ Creating issue: horizontalLabelDD
# 🔄 Running: gh issue create --repo WCRP-CMIP/CVsTT-Project-Planning --title horizontalLabelDD --body "# Global Attribute Review
#
# ## Status
# - [ ] Started
# - [ ] Discussed
# - [ ] Awaiting feedback
#
# ## Details
# Source: Karl's document" --label DRS --label GlobalAttribute --label CVsTT --label KarlDocument --milestone DRS
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/12
# ✅ Issue created successfully
#
# 🔍 Getting issue information from: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/12
# 🔄 Running: gh issue view https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/12 --json id,number,title,body,state
# Return code: 0
# Stdout: {
#   "body": "\"# Global Attribute Review\n\n## Status\n- [ ] Started\n- [ ] Discussed\n- [ ] Awaiting feedback\n\n## Details\nSource: Karl's document\"",
#   "id": "I_kwDOO23ghc66Jtm5",
#   "number": 12,
# ...
# ✅ Issue retrieved: #12 - horizontalLabelDD
#
# ➕ Adding issue to project with dates...
#
# ➕ Adding issue to project...
# 🔄 Running: gh api graphql -f query=
#         mutation($projectId: ID!, $contentId: ID!) {
#           addProjectV2ItemById(input: {projectId: $projectId, contentId: $contentId}) {
#             item {
#               id
#             }
#           }
#         }
#          -F projectId=PVT_kwDOATRwu84A60Fm -F contentId=I_kwDOO23ghc66Jtm5
# Return code: 0
# Stdout: {
#   "data": {
#     "addProjectV2ItemById": {
#       "item": {
#         "id": "PVTI_lADOATRwu84A60FmzgbMfoU"
#       }
#     }
#   }
# }
# ✅ Issue added to project
#
# 🔍 Searching for issue in project...
# 🔄 Running: gh api graphql -f query=
#         query ($projectId: ID!) {
#           node(id: $projectId) {
#             ... on ProjectV2 {
#               items(first: 100) {
#                 nodes {
#                   id
#                   content {
#                     ... on Issue {
#                       id
#                       number
#                       title
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#          -F projectId=PVT_kwDOATRwu84A60Fm
# Return code: 0
# Stdout: {
#   "data": {
#     "node": {
#       "items": {
#         "nodes": [
#           {
#             "id": "PVTI_lADOATRwu84A60FmzgbMdYo",
#             "content": {
#               "id": "I_kwDOO23ghc66JWE3",
#        ...
# Found 12 items in project
# ✅ Issue found in project! Item ID: PVTI_lADOATRwu84A60FmzgbMfoU
#
# 🔍 Getting project fields...
# 🔄 Running: gh api graphql -f query=
#         query ($projectId: ID!) {
#           node(id: $projectId) {
#             ... on ProjectV2 {
#               fields(first: 50) {
#                 nodes {
#                   __typename
#                   ... on ProjectV2FieldCommon {
#                     id
#                     name
#                     dataType
#                   }
#                 }
#               }
#             }
#           }
#         }
#          -F projectId=PVT_kwDOATRwu84A60Fm
# Return code: 0
# Stdout: {
#   "data": {
#     "node": {
#       "fields": {
#         "nodes": [
#           {
#             "__typename": "ProjectV2Field",
#             "id": "PVTF_lADOATRwu84A60FmzgvTD3k",
#             "name": "Title",
# ...
#   - Title: PVTF_lADOATRwu84A60FmzgvTD3k
#   - Assignees: PVTF_lADOATRwu84A60FmzgvTD3o
#   - Status: PVTSSF_lADOATRwu84A60FmzgvTD3s
#   - Labels: PVTF_lADOATRwu84A60FmzgvTD3w
#   - Linked pull requests: PVTF_lADOATRwu84A60FmzgvTD30
#   - Milestone: PVTF_lADOATRwu84A60FmzgvTD34
#   - Repository: PVTF_lADOATRwu84A60FmzgvTD38
#   - Reviewers: PVTF_lADOATRwu84A60FmzgvTD4E
#   - Parent issue: PVTF_lADOATRwu84A60FmzgvTD4I
#   - Sub-issues progress: PVTF_lADOATRwu84A60FmzgvTD4M
#   - Team: PVTSSF_lADOATRwu84A60FmzgvTEAA
#   - Iteration: PVTIF_lADOATRwu84A60FmzgvTEAE
#   - Quarter: PVTIF_lADOATRwu84A60FmzgvTEAI
#   - Start date: PVTF_lADOATRwu84A60FmzgvTEAM
#   - End date: PVTF_lADOATRwu84A60FmzgvTEAQ
#
# 📝 Updating multiple project fields...
# 📝 Updating 'Start date' to '2025-05-29'
# 🔄 Running: gh api graphql -f query=
#             mutation($projectId: ID!, $itemId: ID!, $fieldId: ID!, $value: Date!) {
#               updateProjectV2ItemFieldValue(input: {
#                 projectId: $projectId
#                 itemId: $itemId
#                 fieldId: $fieldId
#                 value: { date: $value }
#               }) {
#                 projectV2Item {
#                   id
#                 }
#               }
#             }
#              -F projectId=PVT_kwDOATRwu84A60Fm -F itemId=PVTI_lADOATRwu84A60FmzgbMfoU -F fieldId=PVTF_lADOATRwu84A60FmzgvTEAM -F value=2025-05-29
# Return code: 0
# Stdout: {
#   "data": {
#     "updateProjectV2ItemFieldValue": {
#       "projectV2Item": {
#         "id": "PVTI_lADOATRwu84A60FmzgbMfoU"
#       }
#     }
#   }
# }
# ✅ 'Start date' updated successfully
# 📝 Updating 'End date' to '2025-06-12'
# 🔄 Running: gh api graphql -f query=
#             mutation($projectId: ID!, $itemId: ID!, $fieldId: ID!, $value: Date!) {
#               updateProjectV2ItemFieldValue(input: {
#                 projectId: $projectId
#                 itemId: $itemId
#                 fieldId: $fieldId
#                 value: { date: $value }
#               }) {
#                 projectV2Item {
#                   id
#                 }
#               }
#             }
#              -F projectId=PVT_kwDOATRwu84A60Fm -F itemId=PVTI_lADOATRwu84A60FmzgbMfoU -F fieldId=PVTF_lADOATRwu84A60FmzgvTEAQ -F value=2025-06-12
# Return code: 0
# Stdout: {
#   "data": {
#     "updateProjectV2ItemFieldValue": {
#       "projectV2Item": {
#         "id": "PVTI_lADOATRwu84A60FmzgbMfoU"
#       }
#     }
#   }
# }
# ✅ 'End date' updated successfully
# ✅ Updated 2/2 fields successfully
# ✅ Issue added to project with dates: 2025-05-29 to 2025-06-12
# ✅ Created successfully
#
# [4/40] Processing: verticalDD
#
# ➕ Creating issue: verticalDD
# 🔄 Running: gh issue create --repo WCRP-CMIP/CVsTT-Project-Planning --title verticalDD --body "# Global Attribute Review
#
# ## Status
# - [ ] Started
# - [ ] Discussed
# - [ ] Awaiting feedback
#
# ## Details
# Source: Karl's document" --label DRS --label GlobalAttribute --label CVsTT --label KarlDocument --milestone DRS
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/13
# ✅ Issue created successfully
#
# 🔍 Getting issue information from: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/13
# 🔄 Running: gh issue view https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/13 --json id,number,title,body,state
# Return code: 0
# Stdout: {
#   "body": "\"# Global Attribute Review\n\n## Status\n- [ ] Started\n- [ ] Discussed\n- [ ] Awaiting feedback\n\n## Details\nSource: Karl's document\"",
#   "id": "I_kwDOO23ghc66JttV",
#   "number": 13,
# ...
# ✅ Issue retrieved: #13 - verticalDD
#
# ➕ Adding issue to project with dates...
#
# ➕ Adding issue to project...
# 🔄 Running: gh api graphql -f query=
#         mutation($projectId: ID!, $contentId: ID!) {
#           addProjectV2ItemById(input: {projectId: $projectId, contentId: $contentId}) {
#             item {
#               id
#             }
#           }
#         }
#          -F projectId=PVT_kwDOATRwu84A60Fm -F contentId=I_kwDOO23ghc66JttV
# Return code: 0
# Stdout: {
#   "data": {
#     "addProjectV2ItemById": {
#       "item": {
#         "id": "PVTI_lADOATRwu84A60FmzgbMfow"
#       }
#     }
#   }
# }
# ✅ Issue added to project
#
# 🔍 Searching for issue in project...
# 🔄 Running: gh api graphql -f query=
#         query ($projectId: ID!) {
#           node(id: $projectId) {
#             ... on ProjectV2 {
#               items(first: 100) {
#                 nodes {
#                   id
#                   content {
#                     ... on Issue {
#                       id
#                       number
#                       title
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#          -F projectId=PVT_kwDOATRwu84A60Fm
# Return code: 0
# Stdout: {
#   "data": {
#     "node": {
#       "items": {
#         "nodes": [
#           {
#             "id": "PVTI_lADOATRwu84A60FmzgbMdYo",
#             "content": {
#               "id": "I_kwDOO23ghc66JWE3",
#        ...
# Found 13 items in project
# ✅ Issue found in project! Item ID: PVTI_lADOATRwu84A60FmzgbMfow
#
# 🔍 Getting project fields...
# 🔄 Running: gh api graphql -f query=
#         query ($projectId: ID!) {
#           node(id: $projectId) {
#             ... on ProjectV2 {
#               fields(first: 50) {
#                 nodes {
#                   __typename
#                   ... on ProjectV2FieldCommon {
#                     id
#                     name
#                     dataType
#                   }
#                 }
#               }
#             }
#           }
#         }
#          -F projectId=PVT_kwDOATRwu84A60Fm
# Return code: 0
# Stdout: {
#   "data": {
#     "node": {
#       "fields": {
#         "nodes": [
#           {
#             "__typename": "ProjectV2Field",
#             "id": "PVTF_lADOATRwu84A60FmzgvTD3k",
#             "name": "Title",
# ...
#   - Title: PVTF_lADOATRwu84A60FmzgvTD3k
#   - Assignees: PVTF_lADOATRwu84A60FmzgvTD3o
#   - Status: PVTSSF_lADOATRwu84A60FmzgvTD3s
#   - Labels: PVTF_lADOATRwu84A60FmzgvTD3w
#   - Linked pull requests: PVTF_lADOATRwu84A60FmzgvTD30
#   - Milestone: PVTF_lADOATRwu84A60FmzgvTD34
#   - Repository: PVTF_lADOATRwu84A60FmzgvTD38
#   - Reviewers: PVTF_lADOATRwu84A60FmzgvTD4E
#   - Parent issue: PVTF_lADOATRwu84A60FmzgvTD4I
#   - Sub-issues progress: PVTF_lADOATRwu84A60FmzgvTD4M
#   - Team: PVTSSF_lADOATRwu84A60FmzgvTEAA
#   - Iteration: PVTIF_lADOATRwu84A60FmzgvTEAE
#   - Quarter: PVTIF_lADOATRwu84A60FmzgvTEAI
#   - Start date: PVTF_lADOATRwu84A60FmzgvTEAM
#   - End date: PVTF_lADOATRwu84A60FmzgvTEAQ
#
# 📝 Updating multiple project fields...
# 📝 Updating 'Start date' to '2025-05-29'
# 🔄 Running: gh api graphql -f query=
#             mutation($projectId: ID!, $itemId: ID!, $fieldId: ID!, $value: Date!) {
#               updateProjectV2ItemFieldValue(input: {
#                 projectId: $projectId
#                 itemId: $itemId
#                 fieldId: $fieldId
#                 value: { date: $value }
#               }) {
#                 projectV2Item {
#                   id
#                 }
#               }
#             }
#              -F projectId=PVT_kwDOATRwu84A60Fm -F itemId=PVTI_lADOATRwu84A60FmzgbMfow -F fieldId=PVTF_lADOATRwu84A60FmzgvTEAM -F value=2025-05-29
# Return code: 0
# Stdout: {
#   "data": {
#     "updateProjectV2ItemFieldValue": {
#       "projectV2Item": {
#         "id": "PVTI_lADOATRwu84A60FmzgbMfow"
#       }
#     }
#   }
# }
# ✅ 'Start date' updated successfully
# 📝 Updating 'End date' to '2025-06-12'
# 🔄 Running: gh api graphql -f query=
#             mutation($projectId: ID!, $itemId: ID!, $fieldId: ID!, $value: Date!) {
#               updateProjectV2ItemFieldValue(input: {
#                 projectId: $projectId
#                 itemId: $itemId
#                 fieldId: $fieldId
#                 value: { date: $value }
#               }) {
#                 projectV2Item {
#                   id
#                 }
#               }
#             }
#              -F projectId=PVT_kwDOATRwu84A60Fm -F itemId=PVTI_lADOATRwu84A60FmzgbMfow -F fieldId=PVTF_lADOATRwu84A60FmzgvTEAQ -F value=2025-06-12
# Return code: 0
# Stdout: {
#   "data": {
#     "updateProjectV2ItemFieldValue": {
#       "projectV2Item": {
#         "id": "PVTI_lADOATRwu84A60FmzgbMfow"
#       }
#     }
#   }
# }
# ✅ 'End date' updated successfully
# ✅ Updated 2/2 fields successfully
# ✅ Issue added to project with dates: 2025-05-29 to 2025-06-12
# ✅ Created successfully
#
# [5/40] Processing: temporalLabelDD
#
# ➕ Creating issue: temporalLabelDD
# 🔄 Running: gh issue create --repo WCRP-CMIP/CVsTT-Project-Planning --title temporalLabelDD --body "# Global Attribute Review
#
# ## Status
# - [ ] Started
# - [ ] Discussed
# - [ ] Awaiting feedback
#
# ## Details
# Source: Karl's document" --label DRS --label GlobalAttribute --label CVsTT --label KarlDocument --milestone DRS
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/14
# ✅ Issue created successfully
#
# 🔍 Getting issue information from: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/14
# 🔄 Running: gh issue view https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/14 --json id,number,title,body,state
# Return code: 0
# Stdout: {
#   "body": "\"# Global Attribute Review\n\n## Status\n- [ ] Started\n- [ ] Discussed\n- [ ] Awaiting feedback\n\n## Details\nSource: Karl's document\"",
#   "id": "I_kwDOO23ghc66Jtv7",
#   "number": 14,
# ...
# ✅ Issue retrieved: #14 - temporalLabelDD
#
# ➕ Adding issue to project with dates...
#
# ➕ Adding issue to project...
# 🔄 Running: gh api graphql -f query=
#         mutation($projectId: ID!, $contentId: ID!) {
#           addProjectV2ItemById(input: {projectId: $projectId, contentId: $contentId}) {
#             item {
#               id
#             }
#           }
#         }
#          -F projectId=PVT_kwDOATRwu84A60Fm -F contentId=I_kwDOO23ghc66Jtv7
# Return code: 0
# Stdout: {
#   "data": {
#     "addProjectV2ItemById": {
#       "item": {
#         "id": "PVTI_lADOATRwu84A60FmzgbMfpM"
#       }
#     }
#   }
# }
# ✅ Issue added to project
#
# 🔍 Searching for issue in project...
# 🔄 Running: gh api graphql -f query=
#         query ($projectId: ID!) {
#           node(id: $projectId) {
#             ... on ProjectV2 {
#               items(first: 100) {
#                 nodes {
#                   id
#                   content {
#                     ... on Issue {
#                       id
#                       number
#                       title
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#          -F projectId=PVT_kwDOATRwu84A60Fm
# Return code: 0
# Stdout: {
#   "data": {
#     "node": {
#       "items": {
#         "nodes": [
#           {
#             "id": "PVTI_lADOATRwu84A60FmzgbMdYo",
#             "content": {
#               "id": "I_kwDOO23ghc66JWE3",
#        ...
# Found 14 items in project
# ✅ Issue found in project! Item ID: PVTI_lADOATRwu84A60FmzgbMfpM
#
# 🔍 Getting project fields...
# 🔄 Running: gh api graphql -f query=
#         query ($projectId: ID!) {
#           node(id: $projectId) {
#             ... on ProjectV2 {
#               fields(first: 50) {
#                 nodes {
#                   __typename
#                   ... on ProjectV2FieldCommon {
#                     id
#                     name
#                     dataType
#                   }
#                 }
#               }
#             }
#           }
#         }
#          -F projectId=PVT_kwDOATRwu84A60Fm
# Return code: 0
# Stdout: {
#   "data": {
#     "node": {
#       "fields": {
#         "nodes": [
#           {
#             "__typename": "ProjectV2Field",
#             "id": "PVTF_lADOATRwu84A60FmzgvTD3k",
#             "name": "Title",
# ...
#   - Title: PVTF_lADOATRwu84A60FmzgvTD3k
#   - Assignees: PVTF_lADOATRwu84A60FmzgvTD3o
#   - Status: PVTSSF_lADOATRwu84A60FmzgvTD3s
#   - Labels: PVTF_lADOATRwu84A60FmzgvTD3w
#   - Linked pull requests: PVTF_lADOATRwu84A60FmzgvTD30
#   - Milestone: PVTF_lADOATRwu84A60FmzgvTD34
#   - Repository: PVTF_lADOATRwu84A60FmzgvTD38
#   - Reviewers: PVTF_lADOATRwu84A60FmzgvTD4E
#   - Parent issue: PVTF_lADOATRwu84A60FmzgvTD4I
#   - Sub-issues progress: PVTF_lADOATRwu84A60FmzgvTD4M
#   - Team: PVTSSF_lADOATRwu84A60FmzgvTEAA
#   - Iteration: PVTIF_lADOATRwu84A60FmzgvTEAE
#   - Quarter: PVTIF_lADOATRwu84A60FmzgvTEAI
#   - Start date: PVTF_lADOATRwu84A60FmzgvTEAM
#   - End date: PVTF_lADOATRwu84A60FmzgvTEAQ
#
# 📝 Updating multiple project fields...
# 📝 Updating 'Start date' to '2025-05-29'
# 🔄 Running: gh api graphql -f query=
#             mutation($projectId: ID!, $itemId: ID!, $fieldId: ID!, $value: Date!) {
#               updateProjectV2ItemFieldValue(input: {
#                 projectId: $projectId
#                 itemId: $itemId
#                 fieldId: $fieldId
#                 value: { date: $value }
#               }) {
#                 projectV2Item {
#                   id
#                 }
#               }
#             }
#              -F projectId=PVT_kwDOATRwu84A60Fm -F itemId=PVTI_lADOATRwu84A60FmzgbMfpM -F fieldId=PVTF_lADOATRwu84A60FmzgvTEAM -F value=2025-05-29
# Return code: 0
# Stdout: {
#   "data": {
#     "updateProjectV2ItemFieldValue": {
#       "projectV2Item": {
#         "id": "PVTI_lADOATRwu84A60FmzgbMfpM"
#       }
#     }
#   }
# }
# ✅ 'Start date' updated successfully
# 📝 Updating 'End date' to '2025-06-12'
# 🔄 Running: gh api graphql -f query=
#             mutation($projectId: ID!, $itemId: ID!, $fieldId: ID!, $value: Date!) {
#               updateProjectV2ItemFieldValue(input: {
#                 projectId: $projectId
#                 itemId: $itemId
#                 fieldId: $fieldId
#                 value: { date: $value }
#               }) {
#                 projectV2Item {
#                   id
#                 }
#               }
#             }
#              -F projectId=PVT_kwDOATRwu84A60Fm -F itemId=PVTI_lADOATRwu84A60FmzgbMfpM -F fieldId=PVTF_lADOATRwu84A60FmzgvTEAQ -F value=2025-06-12
# Return code: 0
# Stdout: {
#   "data": {
#     "updateProjectV2ItemFieldValue": {
#       "projectV2Item": {
#         "id": "PVTI_lADOATRwu84A60FmzgbMfpM"
#       }
#     }
#   }
# }
# ✅ 'End date' updated successfully
# ✅ Updated 2/2 fields successfully
# ✅ Issue added to project with dates: 2025-05-29 to 2025-06-12
# ✅ Created successfully
#
# [6/40] Processing: area_labelDD
#
# ➕ Creating issue: area_labelDD
# 🔄 Running: gh issue create --repo WCRP-CMIP/CVsTT-Project-Planning --title area_labelDD --body "# Global Attribute Review
#
# ## Status
# - [ ] Started
# - [ ] Discussed
# - [ ] Awaiting feedback
#
# ## Details
# Source: Karl's document" --label DRS --label GlobalAttribute --label CVsTT --label KarlDocument --milestone DRS
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/15
# ✅ Issue created successfully
#
# 🔍 Getting issue information from: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/15
# 🔄 Running: gh issue view https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/15 --json id,number,title,body,state
# Return code: 0
# Stdout: {
#   "body": "\"# Global Attribute Review\n\n## Status\n- [ ] Started\n- [ ] Discussed\n- [ ] Awaiting feedback\n\n## Details\nSource: Karl's document\"",
#   "id": "I_kwDOO23ghc66Jt2C",
#   "number": 15,
# ...
# ✅ Issue retrieved: #15 - area_labelDD
#
# ➕ Adding issue to project with dates...
#
# ➕ Adding issue to project...
# 🔄 Running: gh api graphql -f query=
#         mutation($projectId: ID!, $contentId: ID!) {
#           addProjectV2ItemById(input: {projectId: $projectId, contentId: $contentId}) {
#             item {
#               id
#             }
#           }
#         }
#          -F projectId=PVT_kwDOATRwu84A60Fm -F contentId=I_kwDOO23ghc66Jt2C
# Return code: 0
# Stdout: {
#   "data": {
#     "addProjectV2ItemById": {
#       "item": {
#         "id": "PVTI_lADOATRwu84A60FmzgbMfpk"
#       }
#     }
#   }
# }
# ✅ Issue added to project
#
# 🔍 Searching for issue in project...
# 🔄 Running: gh api graphql -f query=
#         query ($projectId: ID!) {
#           node(id: $projectId) {
#             ... on ProjectV2 {
#               items(first: 100) {
#                 nodes {
#                   id
#                   content {
#                     ... on Issue {
#                       id
#                       number
#                       title
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#          -F projectId=PVT_kwDOATRwu84A60Fm
# Return code: 0
# Stdout: {
#   "data": {
#     "node": {
#       "items": {
#         "nodes": [
#           {
#             "id": "PVTI_lADOATRwu84A60FmzgbMdYo",
#             "content": {
#               "id": "I_kwDOO23ghc66JWE3",
#        ...
# Found 14 items in project
# ✅ Issue found in project! Item ID: PVTI_lADOATRwu84A60FmzgbMfpk
#
# 🔍 Getting project fields...
# 🔄 Running: gh api graphql -f query=
#         query ($projectId: ID!) {
#           node(id: $projectId) {
#             ... on ProjectV2 {
#               fields(first: 50) {
#                 nodes {
#                   __typename
#                   ... on ProjectV2FieldCommon {
#                     id
#                     name
#                     dataType
#                   }
#                 }
#               }
#             }
#           }
#         }
#          -F projectId=PVT_kwDOATRwu84A60Fm
# Return code: 0
# Stdout: {
#   "data": {
#     "node": {
#       "fields": {
#         "nodes": [
#           {
#             "__typename": "ProjectV2Field",
#             "id": "PVTF_lADOATRwu84A60FmzgvTD3k",
#             "name": "Title",
# ...
#   - Title: PVTF_lADOATRwu84A60FmzgvTD3k
#   - Assignees: PVTF_lADOATRwu84A60FmzgvTD3o
#   - Status: PVTSSF_lADOATRwu84A60FmzgvTD3s
#   - Labels: PVTF_lADOATRwu84A60FmzgvTD3w
#   - Linked pull requests: PVTF_lADOATRwu84A60FmzgvTD30
#   - Milestone: PVTF_lADOATRwu84A60FmzgvTD34
#   - Repository: PVTF_lADOATRwu84A60FmzgvTD38
#   - Reviewers: PVTF_lADOATRwu84A60FmzgvTD4E
#   - Parent issue: PVTF_lADOATRwu84A60FmzgvTD4I
#   - Sub-issues progress: PVTF_lADOATRwu84A60FmzgvTD4M
#   - Team: PVTSSF_lADOATRwu84A60FmzgvTEAA
#   - Iteration: PVTIF_lADOATRwu84A60FmzgvTEAE
#   - Quarter: PVTIF_lADOATRwu84A60FmzgvTEAI
#   - Start date: PVTF_lADOATRwu84A60FmzgvTEAM
#   - End date: PVTF_lADOATRwu84A60FmzgvTEAQ
#
# 📝 Updating multiple project fields...
# 📝 Updating 'Start date' to '2025-05-29'
# 🔄 Running: gh api graphql -f query=
#             mutation($projectId: ID!, $itemId: ID!, $fieldId: ID!, $value: Date!) {
#               updateProjectV2ItemFieldValue(input: {
#                 projectId: $projectId
#                 itemId: $itemId
#                 fieldId: $fieldId
#                 value: { date: $value }
#               }) {
#                 projectV2Item {
#                   id
#                 }
#               }
#             }
#              -F projectId=PVT_kwDOATRwu84A60Fm -F itemId=PVTI_lADOATRwu84A60FmzgbMfpk -F fieldId=PVTF_lADOATRwu84A60FmzgvTEAM -F value=2025-05-29
# Return code: 0
# Stdout: {
#   "data": {
#     "updateProjectV2ItemFieldValue": {
#       "projectV2Item": {
#         "id": "PVTI_lADOATRwu84A60FmzgbMfpk"
#       }
#     }
#   }
# }
# ✅ 'Start date' updated successfully
# 📝 Updating 'End date' to '2025-06-12'
# 🔄 Running: gh api graphql -f query=
#             mutation($projectId: ID!, $itemId: ID!, $fieldId: ID!, $value: Date!) {
#               updateProjectV2ItemFieldValue(input: {
#                 projectId: $projectId
#                 itemId: $itemId
#                 fieldId: $fieldId
#                 value: { date: $value }
#               }) {
#                 projectV2Item {
#                   id
#                 }
#               }
#             }
#              -F projectId=PVT_kwDOATRwu84A60Fm -F itemId=PVTI_lADOATRwu84A60FmzgbMfpk -F fieldId=PVTF_lADOATRwu84A60FmzgvTEAQ -F value=2025-06-12
# Return code: 0
# Stdout: {
#   "data": {
#     "updateProjectV2ItemFieldValue": {
#       "projectV2Item": {
#         "id": "PVTI_lADOATRwu84A60FmzgbMfpk"
#       }
#     }
#   }
# }
# ✅ 'End date' updated successfully
# ✅ Updated 2/2 fields successfully
# ✅ Issue added to project with dates: 2025-05-29 to 2025-06-12
# ✅ Created successfully
#
# [7/40] Processing: brandingSuffixDD
#
# ➕ Creating issue: brandingSuffixDD
# 🔄 Running: gh issue create --repo WCRP-CMIP/CVsTT-Project-Planning --title brandingSuffixDD --body "# Global Attribute Review
#
# ## Status
# - [ ] Started
# - [ ] Discussed
# - [ ] Awaiting feedback
#
# ## Details
# Source: Karl's document" --label DRS --label GlobalAttribute --label CVsTT --label KarlDocument --milestone DRS
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/16
# ✅ Issue created successfully
#
# 🔍 Getting issue information from: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/16
# 🔄 Running: gh issue view https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/16 --json id,number,title,body,state
# Return code: 0
# Stdout: {
#   "body": "\"# Global Attribute Review\n\n## Status\n- [ ] Started\n- [ ] Discussed\n- [ ] Awaiting feedback\n\n## Details\nSource: Karl's document\"",
#   "id": "I_kwDOO23ghc66Jt3r",
#   "number": 16,
# ...
# ✅ Issue retrieved: #16 - brandingSuffixDD
#
# ➕ Adding issue to project with dates...
#
# ➕ Adding issue to project...
# 🔄 Running: gh api graphql -f query=
#         mutation($projectId: ID!, $contentId: ID!) {
#           addProjectV2ItemById(input: {projectId: $projectId, contentId: $contentId}) {
#             item {
#               id
#             }
#           }
#         }
#          -F projectId=PVT_kwDOATRwu84A60Fm -F contentId=I_kwDOO23ghc66Jt3r
# Return code: 0
# Stdout: {
#   "data": {
#     "addProjectV2ItemById": {
#       "item": {
#         "id": "PVTI_lADOATRwu84A60FmzgbMfqA"
#       }
#     }
#   }
# }
# ✅ Issue added to project
#
# 🔍 Searching for issue in project...
# 🔄 Running: gh api graphql -f query=
#         query ($projectId: ID!) {
#           node(id: $projectId) {
#             ... on ProjectV2 {
#               items(first: 100) {
#                 nodes {
#                   id
#                   content {
#                     ... on Issue {
#                       id
#                       number
#                       title
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#          -F projectId=PVT_kwDOATRwu84A60Fm
# Return code: 0
# Stdout: {
#   "data": {
#     "node": {
#       "items": {
#         "nodes": [
#           {
#             "id": "PVTI_lADOATRwu84A60FmzgbMdYo",
#             "content": {
#               "id": "I_kwDOO23ghc66JWE3",
#        ...
# Found 15 items in project
# ✅ Issue found in project! Item ID: PVTI_lADOATRwu84A60FmzgbMfqA
#
# 🔍 Getting project fields...
# 🔄 Running: gh api graphql -f query=
#         query ($projectId: ID!) {
#           node(id: $projectId) {
#             ... on ProjectV2 {
#               fields(first: 50) {
#                 nodes {
#                   __typename
#                   ... on ProjectV2FieldCommon {
#                     id
#                     name
#                     dataType
#                   }
#                 }
#               }
#             }
#           }
#         }
#          -F projectId=PVT_kwDOATRwu84A60Fm
# Return code: 0
# Stdout: {
#   "data": {
#     "node": {
#       "fields": {
#         "nodes": [
#           {
#             "__typename": "ProjectV2Field",
#             "id": "PVTF_lADOATRwu84A60FmzgvTD3k",
#             "name": "Title",
# ...
#   - Title: PVTF_lADOATRwu84A60FmzgvTD3k
#   - Assignees: PVTF_lADOATRwu84A60FmzgvTD3o
#   - Status: PVTSSF_lADOATRwu84A60FmzgvTD3s
#   - Labels: PVTF_lADOATRwu84A60FmzgvTD3w
#   - Linked pull requests: PVTF_lADOATRwu84A60FmzgvTD30
#   - Milestone: PVTF_lADOATRwu84A60FmzgvTD34
#   - Repository: PVTF_lADOATRwu84A60FmzgvTD38
#   - Reviewers: PVTF_lADOATRwu84A60FmzgvTD4E
#   - Parent issue: PVTF_lADOATRwu84A60FmzgvTD4I
#   - Sub-issues progress: PVTF_lADOATRwu84A60FmzgvTD4M
#   - Team: PVTSSF_lADOATRwu84A60FmzgvTEAA
#   - Iteration: PVTIF_lADOATRwu84A60FmzgvTEAE
#   - Quarter: PVTIF_lADOATRwu84A60FmzgvTEAI
#   - Start date: PVTF_lADOATRwu84A60FmzgvTEAM
#   - End date: PVTF_lADOATRwu84A60FmzgvTEAQ
#
# 📝 Updating multiple project fields...
# 📝 Updating 'Start date' to '2025-05-29'
# 🔄 Running: gh api graphql -f query=
#             mutation($projectId: ID!, $itemId: ID!, $fieldId: ID!, $value: Date!) {
#               updateProjectV2ItemFieldValue(input: {
#                 projectId: $projectId
#                 itemId: $itemId
#                 fieldId: $fieldId
#                 value: { date: $value }
#               }) {
#                 projectV2Item {
#                   id
#                 }
#               }
#             }
#              -F projectId=PVT_kwDOATRwu84A60Fm -F itemId=PVTI_lADOATRwu84A60FmzgbMfqA -F fieldId=PVTF_lADOATRwu84A60FmzgvTEAM -F value=2025-05-29
# Return code: 0
# Stdout: {
#   "data": {
#     "updateProjectV2ItemFieldValue": {
#       "projectV2Item": {
#         "id": "PVTI_lADOATRwu84A60FmzgbMfqA"
#       }
#     }
#   }
# }
# ✅ 'Start date' updated successfully
# 📝 Updating 'End date' to '2025-06-12'
# 🔄 Running: gh api graphql -f query=
#             mutation($projectId: ID!, $itemId: ID!, $fieldId: ID!, $value: Date!) {
#               updateProjectV2ItemFieldValue(input: {
#                 projectId: $projectId
#                 itemId: $itemId
#                 fieldId: $fieldId
#                 value: { date: $value }
#               }) {
#                 projectV2Item {
#                   id
#                 }
#               }
#             }
#              -F projectId=PVT_kwDOATRwu84A60Fm -F itemId=PVTI_lADOATRwu84A60FmzgbMfqA -F fieldId=PVTF_lADOATRwu84A60FmzgvTEAQ -F value=2025-06-12
# Return code: 0
# Stdout: {
#   "data": {
#     "updateProjectV2ItemFieldValue": {
#       "projectV2Item": {
#         "id": "PVTI_lADOATRwu84A60FmzgbMfqA"
#       }
#     }
#   }
# }
# ✅ 'End date' updated successfully
# ✅ Updated 2/2 fields successfully
# ✅ Issue added to project with dates: 2025-05-29 to 2025-06-12
# ✅ Created successfully
#
# [8/40] Processing: reportingIntervalDD
#
# ➕ Creating issue: reportingIntervalDD
# 🔄 Running: gh issue create --repo WCRP-CMIP/CVsTT-Project-Planning --title reportingIntervalDD --body "# Global Attribute Review
#
# ## Status
# ...
# 🔄 Running: gh issue edit https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/32 --add-assignee taylor13
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/32
# 🔄 Running: gh issue comment https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/32 --body Assigned to team @WCRP-CMIP/CVsTT (represented by @taylor13)
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/32#issuecomment-2947106353
# ✅ Team assignment comment added
#
# 👥 Assigning issue to team 'CVsTT'...
#
# 👥 Listing members of team 'CVsTT'...
# 🔄 Running: gh api /orgs/WCRP-CMIP/teams/CVsTT/members
# Return code: 0
# Stdout: [
#   {
#     "login": "taylor13",
#     "id": 4993439,
#     "node_id": "MDQ6VXNlcjQ5OTM0Mzk=",
#     "avatar_url": "https://avatars.githubusercontent.com/u/4993439?v=4",
#     "gravatar_id": "",
#     "url": "htt...
# ✅ Found 5 team members
# 📝 Assigning to team member: taylor13
# 🔄 Running: gh issue edit https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/33 --add-assignee taylor13
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/33
# 🔄 Running: gh issue comment https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/33 --body Assigned to team @WCRP-CMIP/CVsTT (represented by @taylor13)
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/33#issuecomment-2947106660
# ✅ Team assignment comment added
#
# 👥 Assigning issue to team 'CVsTT'...
#
# 👥 Listing members of team 'CVsTT'...
# 🔄 Running: gh api /orgs/WCRP-CMIP/teams/CVsTT/members
# Return code: 0
# Stdout: [
#   {
#     "login": "taylor13",
#     "id": 4993439,
#     "node_id": "MDQ6VXNlcjQ5OTM0Mzk=",
#     "avatar_url": "https://avatars.githubusercontent.com/u/4993439?v=4",
#     "gravatar_id": "",
#     "url": "htt...
# ✅ Found 5 team members
# 📝 Assigning to team member: taylor13
# 🔄 Running: gh issue edit https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/34 --add-assignee taylor13
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/34
# 🔄 Running: gh issue comment https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/34 --body Assigned to team @WCRP-CMIP/CVsTT (represented by @taylor13)
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/34#issuecomment-2947107010
# ✅ Team assignment comment added
#
# 👥 Assigning issue to team 'CVsTT'...
#
# 👥 Listing members of team 'CVsTT'...
# 🔄 Running: gh api /orgs/WCRP-CMIP/teams/CVsTT/members
# Return code: 0
# Stdout: [
#   {
#     "login": "taylor13",
#     "id": 4993439,
#     "node_id": "MDQ6VXNlcjQ5OTM0Mzk=",
#     "avatar_url": "https://avatars.githubusercontent.com/u/4993439?v=4",
#     "gravatar_id": "",
#     "url": "htt...
# ✅ Found 5 team members
# 📝 Assigning to team member: taylor13
# 🔄 Running: gh issue edit https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/35 --add-assignee taylor13
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/35
# 🔄 Running: gh issue comment https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/35 --body Assigned to team @WCRP-CMIP/CVsTT (represented by @taylor13)
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/35#issuecomment-2947107439
# ✅ Team assignment comment added
#
# 👥 Assigning issue to team 'CVsTT'...
#
# 👥 Listing members of team 'CVsTT'...
# 🔄 Running: gh api /orgs/WCRP-CMIP/teams/CVsTT/members
# Return code: 0
# Stdout: [
#   {
#     "login": "taylor13",
#     "id": 4993439,
#     "node_id": "MDQ6VXNlcjQ5OTM0Mzk=",
#     "avatar_url": "https://avatars.githubusercontent.com/u/4993439?v=4",
#     "gravatar_id": "",
#     "url": "htt...
# ✅ Found 5 team members
# 📝 Assigning to team member: taylor13
# 🔄 Running: gh issue edit https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/36 --add-assignee taylor13
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/36
# 🔄 Running: gh issue comment https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/36 --body Assigned to team @WCRP-CMIP/CVsTT (represented by @taylor13)
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/36#issuecomment-2947107831
# ✅ Team assignment comment added
#
# 👥 Assigning issue to team 'CVsTT'...
#
# 👥 Listing members of team 'CVsTT'...
# 🔄 Running: gh api /orgs/WCRP-CMIP/teams/CVsTT/members
# Return code: 0
# Stdout: [
#   {
#     "login": "taylor13",
#     "id": 4993439,
#     "node_id": "MDQ6VXNlcjQ5OTM0Mzk=",
#     "avatar_url": "https://avatars.githubusercontent.com/u/4993439?v=4",
#     "gravatar_id": "",
#     "url": "htt...
# ✅ Found 5 team members
# 📝 Assigning to team member: taylor13
# 🔄 Running: gh issue edit https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/37 --add-assignee taylor13
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/37
# 🔄 Running: gh issue comment https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/37 --body Assigned to team @WCRP-CMIP/CVsTT (represented by @taylor13)
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/37#issuecomment-2947108266
# ✅ Team assignment comment added
#
# 👥 Assigning issue to team 'CVsTT'...
#
# 👥 Listing members of team 'CVsTT'...
# 🔄 Running: gh api /orgs/WCRP-CMIP/teams/CVsTT/members
# Return code: 0
# Stdout: [
#   {
#     "login": "taylor13",
#     "id": 4993439,
#     "node_id": "MDQ6VXNlcjQ5OTM0Mzk=",
#     "avatar_url": "https://avatars.githubusercontent.com/u/4993439?v=4",
#     "gravatar_id": "",
#     "url": "htt...
# ✅ Found 5 team members
# 📝 Assigning to team member: taylor13
# 🔄 Running: gh issue edit https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/38 --add-assignee taylor13
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/38
# 🔄 Running: gh issue comment https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/38 --body Assigned to team @WCRP-CMIP/CVsTT (represented by @taylor13)
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/38#issuecomment-2947108714
# ✅ Team assignment comment added
#
# 👥 Assigning issue to team 'CVsTT'...
#
# 👥 Listing members of team 'CVsTT'...
# 🔄 Running: gh api /orgs/WCRP-CMIP/teams/CVsTT/members
# Return code: 0
# Stdout: [
#   {
#     "login": "taylor13",
#     "id": 4993439,
#     "node_id": "MDQ6VXNlcjQ5OTM0Mzk=",
#     "avatar_url": "https://avatars.githubusercontent.com/u/4993439?v=4",
#     "gravatar_id": "",
#     "url": "htt...
# ✅ Found 5 team members
# 📝 Assigning to team member: taylor13
# 🔄 Running: gh issue edit https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/39 --add-assignee taylor13
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/39
# 🔄 Running: gh issue comment https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/39 --body Assigned to team @WCRP-CMIP/CVsTT (represented by @taylor13)
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/39#issuecomment-2947109153
# ✅ Team assignment comment added
#
# 👥 Assigning issue to team 'CVsTT'...
#
# 👥 Listing members of team 'CVsTT'...
# 🔄 Running: gh api /orgs/WCRP-CMIP/teams/CVsTT/members
# Return code: 0
# Stdout: [
#   {
#     "login": "taylor13",
#     "id": 4993439,
#     "node_id": "MDQ6VXNlcjQ5OTM0Mzk=",
#     "avatar_url": "https://avatars.githubusercontent.com/u/4993439?v=4",
#     "gravatar_id": "",
#     "url": "htt...
# ✅ Found 5 team members
# 📝 Assigning to team member: taylor13
# 🔄 Running: gh issue edit https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/40 --add-assignee taylor13
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/40
# 🔄 Running: gh issue comment https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/40 --body Assigned to team @WCRP-CMIP/CVsTT (represented by @taylor13)
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/40#issuecomment-2947109521
# ✅ Team assignment comment added
#
# 👥 Assigning issue to team 'CVsTT'...
#
# 👥 Listing members of team 'CVsTT'...
# 🔄 Running: gh api /orgs/WCRP-CMIP/teams/CVsTT/members
# Return code: 0
# Stdout: [
#   {
#     "login": "taylor13",
#     "id": 4993439,
#     "node_id": "MDQ6VXNlcjQ5OTM0Mzk=",
#     "avatar_url": "https://avatars.githubusercontent.com/u/4993439?v=4",
#     "gravatar_id": "",
#     "url": "htt...
# ✅ Found 5 team members
# 📝 Assigning to team member: taylor13
# 🔄 Running: gh issue edit https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/41 --add-assignee taylor13
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/41
# 🔄 Running: gh issue comment https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/41 --body Assigned to team @WCRP-CMIP/CVsTT (represented by @taylor13)
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/41#issuecomment-2947110046
# ✅ Team assignment comment added
#
# 👥 Assigning issue to team 'CVsTT'...
#
# 👥 Listing members of team 'CVsTT'...
# 🔄 Running: gh api /orgs/WCRP-CMIP/teams/CVsTT/members
# Return code: 0
# Stdout: [
#   {
#     "login": "taylor13",
#     "id": 4993439,
#     "node_id": "MDQ6VXNlcjQ5OTM0Mzk=",
#     "avatar_url": "https://avatars.githubusercontent.com/u/4993439?v=4",
#     "gravatar_id": "",
#     "url": "htt...
# ✅ Found 5 team members
# 📝 Assigning to team member: taylor13
# 🔄 Running: gh issue edit https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/42 --add-assignee taylor13
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/42
# 🔄 Running: gh issue comment https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/42 --body Assigned to team @WCRP-CMIP/CVsTT (represented by @taylor13)
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/42#issuecomment-2947110409
# ✅ Team assignment comment added
#
# 👥 Assigning issue to team 'CVsTT'...
#
# 👥 Listing members of team 'CVsTT'...
# 🔄 Running: gh api /orgs/WCRP-CMIP/teams/CVsTT/members
# Return code: 0
# Stdout: [
#   {
#     "login": "taylor13",
#     "id": 4993439,
#     "node_id": "MDQ6VXNlcjQ5OTM0Mzk=",
#     "avatar_url": "https://avatars.githubusercontent.com/u/4993439?v=4",
#     "gravatar_id": "",
#     "url": "htt...
# ✅ Found 5 team members
# 📝 Assigning to team member: taylor13
# 🔄 Running: gh issue edit https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/43 --add-assignee taylor13
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/43
# 🔄 Running: gh issue comment https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/43 --body Assigned to team @WCRP-CMIP/CVsTT (represented by @taylor13)
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/43#issuecomment-2947110708
# ✅ Team assignment comment added
#
# 👥 Assigning issue to team 'CVsTT'...
#
# 👥 Listing members of team 'CVsTT'...
# 🔄 Running: gh api /orgs/WCRP-CMIP/teams/CVsTT/members
# Return code: 0
# Stdout: [
#   {
#     "login": "taylor13",
#     "id": 4993439,
#     "node_id": "MDQ6VXNlcjQ5OTM0Mzk=",
#     "avatar_url": "https://avatars.githubusercontent.com/u/4993439?v=4",
#     "gravatar_id": "",
#     "url": "htt...
# ✅ Found 5 team members
# 📝 Assigning to team member: taylor13
# 🔄 Running: gh issue edit https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/44 --add-assignee taylor13
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/44
# 🔄 Running: gh issue comment https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/44 --body Assigned to team @WCRP-CMIP/CVsTT (represented by @taylor13)
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/44#issuecomment-2947110817
# ✅ Team assignment comment added
#
# 👥 Assigning issue to team 'CVsTT'...
#
# 👥 Listing members of team 'CVsTT'...
# 🔄 Running: gh api /orgs/WCRP-CMIP/teams/CVsTT/members
# Return code: 0
# Stdout: [
#   {
#     "login": "taylor13",
#     "id": 4993439,
#     "node_id": "MDQ6VXNlcjQ5OTM0Mzk=",
#     "avatar_url": "https://avatars.githubusercontent.com/u/4993439?v=4",
#     "gravatar_id": "",
#     "url": "htt...
# ✅ Found 5 team members
# 📝 Assigning to team member: taylor13
# 🔄 Running: gh issue edit https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/45 --add-assignee taylor13
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/45
# 🔄 Running: gh issue comment https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/45 --body Assigned to team @WCRP-CMIP/CVsTT (represented by @taylor13)
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/45#issuecomment-2947111070
# ✅ Team assignment comment added
#
# 👥 Assigning issue to team 'CVsTT'...
#
# 👥 Listing members of team 'CVsTT'...
# 🔄 Running: gh api /orgs/WCRP-CMIP/teams/CVsTT/members
# Return code: 0
# Stdout: [
#   {
#     "login": "taylor13",
#     "id": 4993439,
#     "node_id": "MDQ6VXNlcjQ5OTM0Mzk=",
#     "avatar_url": "https://avatars.githubusercontent.com/u/4993439?v=4",
#     "gravatar_id": "",
#     "url": "htt...
# ✅ Found 5 team members
# 📝 Assigning to team member: taylor13
# 🔄 Running: gh issue edit https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/46 --add-assignee taylor13
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/46
# 🔄 Running: gh issue comment https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/46 --body Assigned to team @WCRP-CMIP/CVsTT (represented by @taylor13)
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/46#issuecomment-2947111373
# ✅ Team assignment comment added
#
# 👥 Assigning issue to team 'CVsTT'...
#
# 👥 Listing members of team 'CVsTT'...
# 🔄 Running: gh api /orgs/WCRP-CMIP/teams/CVsTT/members
# Return code: 0
# Stdout: [
#   {
#     "login": "taylor13",
#     "id": 4993439,
#     "node_id": "MDQ6VXNlcjQ5OTM0Mzk=",
#     "avatar_url": "https://avatars.githubusercontent.com/u/4993439?v=4",
#     "gravatar_id": "",
#     "url": "htt...
# ✅ Found 5 team members
# 📝 Assigning to team member: taylor13
# 🔄 Running: gh issue edit https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/47 --add-assignee taylor13
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/47
# 🔄 Running: gh issue comment https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/47 --body Assigned to team @WCRP-CMIP/CVsTT (represented by @taylor13)
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/47#issuecomment-2947111697
# ✅ Team assignment comment added
#
# 👥 Assigning issue to team 'CVsTT'...
#
# 👥 Listing members of team 'CVsTT'...
# 🔄 Running: gh api /orgs/WCRP-CMIP/teams/CVsTT/members
# Return code: 0
# Stdout: [
#   {
#     "login": "taylor13",
#     "id": 4993439,
#     "node_id": "MDQ6VXNlcjQ5OTM0Mzk=",
#     "avatar_url": "https://avatars.githubusercontent.com/u/4993439?v=4",
#     "gravatar_id": "",
#     "url": "htt...
# ✅ Found 5 team members
# 📝 Assigning to team member: taylor13
# 🔄 Running: gh issue edit https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/48 --add-assignee taylor13
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/48
# 🔄 Running: gh issue comment https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/48 --body Assigned to team @WCRP-CMIP/CVsTT (represented by @taylor13)
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/48#issuecomment-2947111983
# ✅ Team assignment comment added
#
# 👥 Assigning issue to team 'CVsTT'...
#
# 👥 Listing members of team 'CVsTT'...
# 🔄 Running: gh api /orgs/WCRP-CMIP/teams/CVsTT/members
# Return code: 0
# Stdout: [
#   {
#     "login": "taylor13",
#     "id": 4993439,
#     "node_id": "MDQ6VXNlcjQ5OTM0Mzk=",
#     "avatar_url": "https://avatars.githubusercontent.com/u/4993439?v=4",
#     "gravatar_id": "",
#     "url": "htt...
# ✅ Found 5 team members
# 📝 Assigning to team member: taylor13
# 🔄 Running: gh issue edit https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/49 --add-assignee taylor13
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/49
# 🔄 Running: gh issue comment https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/49 --body Assigned to team @WCRP-CMIP/CVsTT (represented by @taylor13)
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/49#issuecomment-2947112375
# ✅ Team assignment comment added

# %%
# create_new(other)

# %%
help(
issue_mgr.create_issues_bulk )
# Out:
# Help on method create_issues_bulk in module cmipld.utils.git.projects.issues:
#
# create_issues_bulk(repo_owner, repo_name, issues_data, add_to_project_id=None) method of cmipld.utils.git.projects.issues.IssueManager instance
#     Create multiple issues from structured data with optional project integration

# %%
import os,json
urls = [i['url'] for i in json.loads(ghutils.run_gh_cmd('issue list --repo WCRP-CMIP/CVsTT-Project-Planning --limit 1000 --json url'.split()))]

teams.create_child_team(ORG, 'CVsTT', 'CVs-Framework', description='All things technical to do with the CV infrastructure and framework.',)
for url in urls:
    teams.assign_issue_to_team(url, ORG, 'CVs-Framework')
# Out:
# 🔄 Running: gh issue list --repo WCRP-CMIP/CVsTT-Project-Planning --limit 1000 --json url
# Return code: 0
# Stdout: [
#   {
#     "url": "https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/9"
#   },
#   {
#     "url": "https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/8"
#   },
#   {
#     "url": "https://github.c...
#
# ➕ Creating child team 'CVs-Framework' under 'CVsTT'...
# 🔄 Running: gh api /orgs/WCRP-CMIP/teams/CVsTT
# Return code: 0
# Stdout: {
#   "name": "CVsTT",
#   "id": 12650392,
#   "node_id": "T_kwDOATRwu84AwQeY",
#   "slug": "cvstt",
#   "description": "CVs task team",
#   "privacy": "closed",
#   "notification_setting": "notifications_enabled",...
#
# ➕ Creating team 'CVs-Framework'...
# 🔄 Running: gh api /orgs/WCRP-CMIP/teams --method POST --input -
# Return code: 1
# Stdout: {
#   "message": "Validation Failed",
#   "errors": [
#     {
#       "resource": "Team",
#       "code": "unprocessable",
#       "field": "data",
#       "message": "Name must be unique for this org"
#     }
#   ],
#  ...
# Stderr: gh: Validation Failed (HTTP 422)
#
# ❌ Error creating team 'CVs-Framework': Command failed: api /orgs/WCRP-CMIP/teams --method POST --input -
# Error: gh: Validation Failed (HTTP 422)
#
#
# 👥 Assigning issue to team 'CVs-Framework'...
#
# 👥 Listing members of team 'CVs-Framework'...
# 🔄 Running: gh api /orgs/WCRP-CMIP/teams/CVs-Framework/members
# Return code: 0
# Stdout: [
#   {
#     "login": "wolfiex",
#     "id": 15582577,
#     "node_id": "MDQ6VXNlcjE1NTgyNTc3",
#     "avatar_url": "https://avatars.githubusercontent.com/u/15582577?v=4",
#     "gravatar_id": "",
#     "url": "ht...
# ✅ Found 2 team members
# 📝 Assigning to team member: wolfiex
# 🔄 Running: gh issue edit https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/9 --add-assignee wolfiex
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/9
# 🔄 Running: gh issue comment https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/9 --body Assigned to team @WCRP-CMIP/CVs-Framework (represented by @wolfiex)
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/9#issuecomment-2946979279
# ✅ Team assignment comment added
#
# 👥 Assigning issue to team 'CVs-Framework'...
#
# 👥 Listing members of team 'CVs-Framework'...
# 🔄 Running: gh api /orgs/WCRP-CMIP/teams/CVs-Framework/members
# Return code: 0
# Stdout: [
#   {
#     "login": "wolfiex",
#     "id": 15582577,
#     "node_id": "MDQ6VXNlcjE1NTgyNTc3",
#     "avatar_url": "https://avatars.githubusercontent.com/u/15582577?v=4",
#     "gravatar_id": "",
#     "url": "ht...
# ✅ Found 2 team members
# 📝 Assigning to team member: wolfiex
# 🔄 Running: gh issue edit https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/8 --add-assignee wolfiex
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/8
# 🔄 Running: gh issue comment https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/8 --body Assigned to team @WCRP-CMIP/CVs-Framework (represented by @wolfiex)
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/8#issuecomment-2946979355
# ✅ Team assignment comment added
#
# 👥 Assigning issue to team 'CVs-Framework'...
#
# 👥 Listing members of team 'CVs-Framework'...
# 🔄 Running: gh api /orgs/WCRP-CMIP/teams/CVs-Framework/members
# Return code: 0
# Stdout: [
#   {
#     "login": "wolfiex",
#     "id": 15582577,
#     "node_id": "MDQ6VXNlcjE1NTgyNTc3",
#     "avatar_url": "https://avatars.githubusercontent.com/u/15582577?v=4",
#     "gravatar_id": "",
#     "url": "ht...
# ✅ Found 2 team members
# 📝 Assigning to team member: wolfiex
# 🔄 Running: gh issue edit https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/7 --add-assignee wolfiex
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/7
# 🔄 Running: gh issue comment https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/7 --body Assigned to team @WCRP-CMIP/CVs-Framework (represented by @wolfiex)
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/7#issuecomment-2946979411
# ✅ Team assignment comment added
#
# 👥 Assigning issue to team 'CVs-Framework'...
#
# 👥 Listing members of team 'CVs-Framework'...
# 🔄 Running: gh api /orgs/WCRP-CMIP/teams/CVs-Framework/members
# Return code: 0
# Stdout: [
#   {
#     "login": "wolfiex",
#     "id": 15582577,
#     "node_id": "MDQ6VXNlcjE1NTgyNTc3",
#     "avatar_url": "https://avatars.githubusercontent.com/u/15582577?v=4",
#     "gravatar_id": "",
#     "url": "ht...
# ✅ Found 2 team members
# 📝 Assigning to team member: wolfiex
# 🔄 Running: gh issue edit https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/6 --add-assignee wolfiex
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/6
# 🔄 Running: gh issue comment https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/6 --body Assigned to team @WCRP-CMIP/CVs-Framework (represented by @wolfiex)
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/6#issuecomment-2946979631
# ✅ Team assignment comment added
#
# 👥 Assigning issue to team 'CVs-Framework'...
#
# 👥 Listing members of team 'CVs-Framework'...
# 🔄 Running: gh api /orgs/WCRP-CMIP/teams/CVs-Framework/members
# Return code: 0
# Stdout: [
#   {
#     "login": "wolfiex",
#     "id": 15582577,
#     "node_id": "MDQ6VXNlcjE1NTgyNTc3",
#     "avatar_url": "https://avatars.githubusercontent.com/u/15582577?v=4",
#     "gravatar_id": "",
#     "url": "ht...
# ✅ Found 2 team members
# 📝 Assigning to team member: wolfiex
# 🔄 Running: gh issue edit https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/5 --add-assignee wolfiex
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/5
# 🔄 Running: gh issue comment https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/5 --body Assigned to team @WCRP-CMIP/CVs-Framework (represented by @wolfiex)
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/5#issuecomment-2946979763
# ✅ Team assignment comment added
#
# 👥 Assigning issue to team 'CVs-Framework'...
#
# 👥 Listing members of team 'CVs-Framework'...
# 🔄 Running: gh api /orgs/WCRP-CMIP/teams/CVs-Framework/members
# Return code: 0
# Stdout: [
#   {
#     "login": "wolfiex",
#     "id": 15582577,
#     "node_id": "MDQ6VXNlcjE1NTgyNTc3",
#     "avatar_url": "https://avatars.githubusercontent.com/u/15582577?v=4",
#     "gravatar_id": "",
#     "url": "ht...
# ✅ Found 2 team members
# 📝 Assigning to team member: wolfiex
# 🔄 Running: gh issue edit https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/4 --add-assignee wolfiex
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/4
# 🔄 Running: gh issue comment https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/4 --body Assigned to team @WCRP-CMIP/CVs-Framework (represented by @wolfiex)
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/4#issuecomment-2946980229
# ✅ Team assignment comment added
#
# 👥 Assigning issue to team 'CVs-Framework'...
#
# 👥 Listing members of team 'CVs-Framework'...
# 🔄 Running: gh api /orgs/WCRP-CMIP/teams/CVs-Framework/members
# Return code: 0
# Stdout: [
#   {
#     "login": "wolfiex",
#     "id": 15582577,
#     "node_id": "MDQ6VXNlcjE1NTgyNTc3",
#     "avatar_url": "https://avatars.githubusercontent.com/u/15582577?v=4",
#     "gravatar_id": "",
#     "url": "ht...
# ✅ Found 2 team members
# 📝 Assigning to team member: wolfiex
# 🔄 Running: gh issue edit https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/3 --add-assignee wolfiex
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/3
# 🔄 Running: gh issue comment https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/3 --body Assigned to team @WCRP-CMIP/CVs-Framework (represented by @wolfiex)
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/3#issuecomment-2946980676
# ✅ Team assignment comment added
#
# 👥 Assigning issue to team 'CVs-Framework'...
#
# 👥 Listing members of team 'CVs-Framework'...
# 🔄 Running: gh api /orgs/WCRP-CMIP/teams/CVs-Framework/members
# Return code: 0
# Stdout: [
#   {
#     "login": "wolfiex",
#     "id": 15582577,
#     "node_id": "MDQ6VXNlcjE1NTgyNTc3",
#     "avatar_url": "https://avatars.githubusercontent.com/u/15582577?v=4",
#     "gravatar_id": "",
#     "url": "ht...
# ✅ Found 2 team members
# 📝 Assigning to team member: wolfiex
# 🔄 Running: gh issue edit https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/2 --add-assignee wolfiex
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/2
# 🔄 Running: gh issue comment https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/2 --body Assigned to team @WCRP-CMIP/CVs-Framework (represented by @wolfiex)
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/2#issuecomment-2946980958
# ✅ Team assignment comment added
#
# 👥 Assigning issue to team 'CVs-Framework'...
#
# 👥 Listing members of team 'CVs-Framework'...
# 🔄 Running: gh api /orgs/WCRP-CMIP/teams/CVs-Framework/members
# Return code: 0
# Stdout: [
#   {
#     "login": "wolfiex",
#     "id": 15582577,
#     "node_id": "MDQ6VXNlcjE1NTgyNTc3",
#     "avatar_url": "https://avatars.githubusercontent.com/u/15582577?v=4",
#     "gravatar_id": "",
#     "url": "ht...
# ✅ Found 2 team members
# 📝 Assigning to team member: wolfiex
# 🔄 Running: gh issue edit https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/1 --add-assignee wolfiex
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/1
# 🔄 Running: gh issue comment https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/1 --body Assigned to team @WCRP-CMIP/CVs-Framework (represented by @wolfiex)
# Return code: 0
# Stdout: https://github.com/WCRP-CMIP/CVsTT-Project-Planning/issues/1#issuecomment-2946981120
# ✅ Team assignment comment added
